# %%
import pandas as pd
import numpy as np
import h5py

# load data
df = pd.read_csv (r'data/raw_data/funding_data.csv')

# replace + and - so they are coded as missing
df = df.replace('+', np.NaN, regex=False)
df = df.replace('-', np.NaN, regex=False)
df = df.replace('*', np.NaN, regex=False)

# Export the pandas DataFrame into HDF5
h5File = "data/cleaned_data/funding_data.hdf5";
df.to_hdf(h5File, "/data/cleaned_data");
# Out:
# /srv/conda/envs/notebook/lib/python3.9/site-packages/pandas/core/generic.py:2703: PerformanceWarning:
# your performance may suffer as PyTables will pickle object types that it cannot
# map directly to c-types [inferred_type->mixed,key->block0_values] [items->Index(['research_category', '2008', '2009', '2009_ARRA', '2010', '2010_ARRA',
#        '2011', '2012', '2013', '2014', '2015', '2016', '2017', '2018', '2019',
#        '2020', '2021_Estimated', '2022_Estimated', '2019_US_Mortality_19',
#        '2019_US_Prevalence_SE_19'],
#       dtype='object')]
#
#   pytables.to_hdf(

# %%
# Use pandas again to read data from the hdf5 file to the pandas DataFrame
df = pd.read_hdf(h5File, "/data/cleaned_data");

# %%
df
# Out:
#                         research_category    2008    2009 2009_ARRA    2010  \
# 0          Acquired Cognitive Impairment      NaN     NaN       NaN     NaN
# 1    Acute Respiratory Distress Syndrome      $82    $103       $17    $110
# 2             Adolescent Sexual Activity      NaN     NaN       NaN     $80
# 3                  Agent Orange & Dioxin      $13     $13        $2     $11
# 4                                  Aging   $1,965  $3,015      $554  $2,517
# ..                                    ...     ...     ...       ...     ...
# 294                      West Nile Virus      $39     $59        $7     $46
# 295                      Women's Health 8  $3,514  $3,725      $506  $3,691
# 296               Wound Healing and Care      NaN     NaN       NaN     NaN
# 297                       Youth Violence     $115    $111       $12    $102
# 298            Youth Violence Prevention      NaN     NaN       NaN     $32
#
#     2010_ARRA    2011    2012    2013    2014    2015    2016    2017    2018  \
# 0         NaN     NaN     NaN     NaN     NaN    $798  $1,132  $1,560  $1,978
# 1         $22     $96     $98     $95     $85    $108    $103    $107    $123
# 2          $7     $69     $76     $70     $68     $85     $91     $99     $96
# 3          $1      $8      $8     $10      $8      $9      $9     $11     $10
# 4        $443  $2,572  $2,593  $2,429  $2,556  $2,698  $3,150  $3,572  $4,084
# ..        ...     ...     ...     ...     ...     ...     ...     ...     ...
# 294        $6     $65     $29     $40     $48     $40     $46     $42     $36
# 295      $449  $3,891  $3,833  $3,745  $3,935  $3,989  $4,540  $4,769  $5,048
# 296       NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 297       $10     $87     $77     $70     $59     $47     $46     $50     $46
# 298        $2     $26     $27     $26     $16     $15     $17     $21     $22
#
#        2019    2020 2021_Estimated 2022_Estimated 2019_US_Mortality_19  \
# 0    $2,423  $2,897         $3,212         $3,307                  NaN
# 1      $126    $158           $159           $146               10,482
# 2      $102     $88            $92           $104                  NaN
# 3        $8      $6             $6             $6                  NaN
# 4    $4,653  $5,276         $5,309         $5,498                  NaN
# ..      ...     ...            ...            ...                  ...
# 294     $24     $27            $27            $28                   90
# 295  $4,469  $4,466         $4,537         $4,779                  NaN
# 296     NaN    $163           $167           $172                  NaN
# 297     $48     $38            $40            $46                  NaN
# 298     $24     $21            $23            $27                  NaN
#
#     2019_US_Prevalence_SE_19
# 0                        NaN
# 1                        NaN
# 2                        NaN
# 3                        NaN
# 4                        NaN
# ..                       ...
# 294                      NaN
# 295                      NaN
# 296                      NaN
# 297                      NaN
# 298                      NaN
#
# [299 rows x 20 columns]

# %%
data2019 = df[["research_category", "2019"]]

#data2019["2019"] = data2019["2019"].apply(lambda x: float(str(x)[1:].replace(",", "")) if x is not None else None)
data2019['2019'] = data2019['2019'].replace('[\$,]', '', regex=True).astype(float)

datatop10 = data2019.sort_values("2019", ascending=False)[:10]
datatop10
# Out:
# /tmp/ipykernel_197/3739999749.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data2019['2019'] = data2019['2019'].replace('[\$,]', '', regex=True).astype(float)
#                                 research_category     2019
# 60                             Clinical Research   15868.0
# 114                                     Genetics    9864.0
# 225                                   Prevention    9485.0
# 188                                Neurosciences    9468.0
# 33                                 Biotechnology    7219.0
# 36                               Brain Disorders    6954.0
# 41                                        Cancer    6520.0
# 29                 Behavioral and Social Science    6499.0
# 142                          Infectious Diseases    6313.0
# 61   Clinical Trials and Supportive Activities 17   6058.0

# %%
import matplotlib.pyplot as plt

plt.bar(datatop10["research_category"],datatop10["2019"])
plt.xticks(rotation=90)
plt.title("Top 10 Spending Categories in 2019")
plt.xlabel("Spending Category")
plt.ylabel ("Spending ($)");
plt.savefig('figures/fig1.png')

# %%
def change_to_float(data):
    return data.replace('[\$,]', '', regex=True).astype(float)

# %%
data_recent = df[["research_category", "2016", "2017", "2018", "2019", "2020"]]

for item in ["2016", "2017", "2018", "2019", "2020"]:
    data_recent[item] = change_to_float(data_recent[item])
# Out:
# /tmp/ipykernel_197/2195838693.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_recent[item] = change_to_float(data_recent[item])

# %%
data_recent
# Out:
#                         research_category    2016    2017    2018    2019  \
# 0          Acquired Cognitive Impairment   1132.0  1560.0  1978.0  2423.0
# 1    Acute Respiratory Distress Syndrome    103.0   107.0   123.0   126.0
# 2             Adolescent Sexual Activity     91.0    99.0    96.0   102.0
# 3                  Agent Orange & Dioxin      9.0    11.0    10.0     8.0
# 4                                  Aging   3150.0  3572.0  4084.0  4653.0
# ..                                    ...     ...     ...     ...     ...
# 294                      West Nile Virus     46.0    42.0    36.0    24.0
# 295                      Women's Health 8  4540.0  4769.0  5048.0  4469.0
# 296               Wound Healing and Care      NaN     NaN     NaN     NaN
# 297                       Youth Violence     46.0    50.0    46.0    48.0
# 298            Youth Violence Prevention     17.0    21.0    22.0    24.0
#
#        2020
# 0    2897.0
# 1     158.0
# 2      88.0
# 3       6.0
# 4    5276.0
# ..      ...
# 294    27.0
# 295  4466.0
# 296   163.0
# 297    38.0
# 298    21.0
#
# [299 rows x 6 columns]

# %%
data_recent['total'] = data_recent['2016']+data_recent['2017']+data_recent['2018']+data_recent['2019']+data_recent['2020']
datatop5 = data_recent.sort_values("total", ascending=False)[:5]
datatop5 = datatop5[["research_category", "2016", "2017", "2018", "2019", "2020"]]
datatop5
# Out:
# /tmp/ipykernel_197/2820536181.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_recent['total'] = data_recent['2016']+data_recent['2017']+data_recent['2018']+data_recent['2019']+data_recent['2020']
#       research_category     2016     2017     2018     2019     2020
# 60   Clinical Research   12176.0  12695.0  13870.0  15868.0  17610.0
# 114           Genetics    8070.0   8501.0   9105.0   9864.0  10544.0
# 225         Prevention    7566.0   8052.0   8757.0   9485.0  10482.0
# 188      Neurosciences    6460.0   7317.0   8224.0   9468.0  10122.0
# 33       Biotechnology    6433.0   6556.0   6923.0   7219.0   7767.0

# %%
datatop5 = datatop5.set_index('research_category').transpose().reset_index()
datatop5['index'] = (datatop5['index']).astype(int)
datatop5
# Out:
# research_category  index  Clinical Research   Genetics   Prevention   \
# 0                   2016             12176.0     8070.0       7566.0
# 1                   2017             12695.0     8501.0       8052.0
# 2                   2018             13870.0     9105.0       8757.0
# 3                   2019             15868.0     9864.0       9485.0
# 4                   2020             17610.0    10544.0      10482.0
#
# research_category  Neurosciences   Biotechnology
# 0                          6460.0          6433.0
# 1                          7317.0          6556.0
# 2                          8224.0          6923.0
# 3                          9468.0          7219.0
# 4                         10122.0          7767.0

# %%
plt.plot("index", 'Clinical Research ', data = datatop5, label = "Clinical Research");
plt.plot("index", 'Genetics ', data = datatop5, label = "Genetics");
plt.plot("index", 'Prevention ', data = datatop5, label = "Prevention");
plt.plot("index", 'Neurosciences ', data = datatop5, label = "Neurosciences");
plt.plot("index", 'Biotechnology ', data = datatop5, label = "Biotechnology");
plt.xticks(np.arange(2016, 2020+1, 1.0));
plt.xlabel("Year");
plt.ylabel("Spending ($)");
plt.legend();
plt.title("Top 5 Spending Categories Over Time");
plt.savefig('figures/fig2.png')
